# %%
from Data_loader import dummy_enc
from Data_imputation import mf_imputer
import pandas as pd
from sklearn.preprocessing import StandardScaler
from FeatureSelection import Kernal_PCA
from decision_tree_Classifiers import dt_kn_classfifier_kpca, dt_kn_classifier_kpca_kfold, dt_kn_classifier_kpca_stratfold
from GridSearch_params import split_data
from imblearn.over_sampling import SMOTE

# %%
data = pd.read_csv('train.csv')
y1 = data.outcome
x = data.drop(['outcome'], axis=1)

# %%
sscaler = StandardScaler()
sm  = SMOTE(random_state=42)
X_data_enc = dummy_enc(x)
x_data_mean = mf_imputer(X_data_enc)
x_sm, y = sm.fit_resample(x_data_mean, y1)
X_data_sc = sscaler.fit_transform(x_sm)

# %%
y1.hist()
# Out:
# <Axes: >

# %%
y.hist()
# Out:
# <Axes: >

# %%
x_data_pca = Kernal_PCA(X_data_sc)

# %%
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y)

# %%
dt_kn_classfifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# Decision Tree Classifier without using any Cross-Validation Technique with Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.64      0.56      0.60       101
#   euthanized       0.58      0.76      0.66       112
#        lived       0.74      0.61      0.67       132
#
#     accuracy                           0.65       345
#    macro avg       0.65      0.65      0.64       345
# weighted avg       0.66      0.65      0.65       345
#
# Plotting the Confusion Matrix

# %%
dt_kn_classifier_kpca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Decision Tree Classifier with K-Fold Cross-Validation Technique(K = 10) with Kernel PCA Feature Selection
# Classification Report
# 	Precision Score(Macro): 0.64
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.64
# 	Recall Score(Weighted): 0.64
#
# 	F1 Score(Macro): 0.64
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.64
# Plotting the Confusion Matrix

# %%
dt_kn_classifier_kpca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Decision Tree Classifier with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.64
# 	Precision Score(Weighted): 0.64
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.63
#
# 	F1 Score(Macro): 0.63
# 	F1 Score(Weighted): 0.63
# 	Accuracy Score: 0.63
# Plotting the Confusion Matrix

# %%
from random_forest_classifier import rft_kn_classifier_kpca, rft_kn_classifier_kpca_kfold, rft_kn_classifier_kpca_stratfold

# %%
rft_kn_classifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# Random Forest Tree Classifier without using any Cross-Validation Technique and Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.58      0.73      0.65       101
#   euthanized       0.75      0.72      0.74       112
#        lived       0.73      0.61      0.66       132
#
#     accuracy                           0.68       345
#    macro avg       0.69      0.69      0.68       345
# weighted avg       0.69      0.68      0.68       345
#
# Plotting the Confusion Matrix

# %%
rft_kn_classifier_kpca_kfold(x_data_pca,y,  x_tr, x_te, y_tr, y_te)
# Out:
# Random Forest Tree Classifier with K-Fold Cross-Validation Technique(K = 10) and Kernel PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.70
# 	Precision Score(Weighted): 0.71
#
# 	Recall Score(Macro): 0.70
# 	Recall Score(Weighted): 0.70
#
# 	F1 Score(Macro): 0.70
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.70
# Plotting the Confusion Matrix

# %%
rft_kn_classifier_kpca_stratfold(x_data_pca, y,x_tr, x_te, y_tr, y_te )
# Out:
# Random Forest Tree Classifier with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.71
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.71
# 	Recall Score(Weighted): 0.70
#
# 	F1 Score(Macro): 0.71
# 	F1 Score(Weighted): 0.70
# 	Accuracy Score: 0.71
# Plotting the Confusion Matrix

# %%
from logistic_regression_classifier import lr_kn_classifier_kpca, lr_kn_classifier_kpca_kfold, lr_kn_classifier_kpca_stratfold

# %%
lr_kn_classifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# Logistic Regression Classifier without using any Cross-Validation Technique and Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.57      0.70      0.63       101
#   euthanized       0.71      0.64      0.67       112
#        lived       0.74      0.66      0.70       132
#
#     accuracy                           0.67       345
#    macro avg       0.67      0.67      0.67       345
# weighted avg       0.68      0.67      0.67       345
#
# Plotting the Confusion Matrix

# %%
lr_kn_classifier_kpca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Random Forest Tree Classifier with K-Fold Cross-Validation Technique(K = 10) and Kernel PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.64
# 	Precision Score(Weighted): 0.64
#
# 	Recall Score(Macro): 0.64
# 	Recall Score(Weighted): 0.64
#
# 	F1 Score(Macro): 0.64
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.64
# Plotting the Confusion Matrix

# %%
lr_kn_classifier_kpca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Logistic Regression Classifier with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.64
# 	Precision Score(Weighted): 0.64
#
# 	Recall Score(Macro): 0.64
# 	Recall Score(Weighted): 0.64
#
# 	F1 Score(Macro): 0.64
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.64
# Plotting the Confusion Matrix

# %%
from XGBoost_classifier import xgb_kn_classifier_kpca, xgb_kn_classifier_kpca_kfold, xgb_kn_classifier_kpca_stratfold

# %%
data = pd.read_csv('train.csv')
y = data.outcome
x = data.drop(['outcome'], axis=1)
y_enc = dummy_enc(y)
sscaler = StandardScaler()
X_data_enc = dummy_enc(x)
x_data_mean = mf_imputer(X_data_enc)
X_data_sc = sscaler.fit_transform(x_data_mean)
x_data_pca = Kernal_PCA(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y_enc)

# %%
xgb_kn_classifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# XGBoosting Classifier without using any Cross-Validation Technique and Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.48      0.56      0.52        72
#            1       0.53      0.30      0.38        54
#            2       0.70      0.67      0.68       121
#
#    micro avg       0.60      0.55      0.58       247
#    macro avg       0.57      0.51      0.53       247
# weighted avg       0.60      0.55      0.57       247
#  samples avg       0.52      0.55      0.53       247
#
# Plotting the Confusion Matrix
# /home/aarvee/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
xgb_kn_classifier_kpca_kfold(x_data_pca, y_enc, x_tr, x_te, y_tr, y_te)
# Out:
# XGBoosting Classifier with K-Fold Cross-Validation Technique(K = 10) and Kernel PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.61
# 	Precision Score(Weighted): 0.64
#
# 	Recall Score(Macro): 0.52
# 	Recall Score(Weighted): 0.55
#
# 	F1 Score(Macro): 0.59
# 	F1 Score(Weighted): 0.58
# 	Accuracy Score: 0.52
# Plotting the Confusion Matrix

# %%
xgb_kn_classifier_kpca_stratfold(x_data_pca, y_enc, x_tr, x_te, y_tr, y_te)
# Out:
# XGBoosting with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.58
# 	Precision Score(Weighted): 0.60
#
# 	Recall Score(Macro): 0.57
# 	Recall Score(Weighted): 0.60
#
# 	F1 Score(Macro): 0.60
# 	F1 Score(Weighted): 0.60
# 	Accuracy Score: 0.60
# Plotting the Confusion Matrix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 xgb_kn_classifier_kpca_stratfold(x_data_pca, y_enc, x_tr, x_te, y_tr, y_te)
#
# File ~/Desktop/DSE-315-Project/XGBoost_classifier.py:187, in xgb_kn_classifier_kpca_stratfold(x_data, y_data, x_tr, x_te, y_tr, y_te)
#     185 print(f"\tAccuracy Score: {nested_score_acc.mean():.2f}")
#     186 print("Plotting the Confusion Matrix")
# --> 187 y_pr = cross_val_predict(lr_cl_kn_pca_stratf, x_te, y_te, cv = outer_cv)
#     188 cormat = confusion_matrix(np.array(y_te).argmax(axis=1), np.array(y_pr).argmax(axis=1))
#     189 sns.heatmap(cormat, annot=True, fmt='g')
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:960, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     957 X, y, groups = indexable(X, y, groups)
#     959 cv = check_cv(cv, y, classifier=is_classifier(estimator))
# --> 960 splits = list(cv.split(X, y, groups))
#     962 test_indices = np.concatenate([test for _, test in splits])
#     963 if not _check_is_permutation(test_indices, _num_samples(X)):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:352, in _BaseKFold.split(self, X, y, groups)
#     344 if self.n_splits > n_samples:
#     345     raise ValueError(
#     346         (
#     347             "Cannot have number of splits n_splits={0} greater"
#     348             " than the number of samples: n_samples={1}."
#     349         ).format(self.n_splits, n_samples)
#     350     )
# --> 352 for train, test in super().split(X, y, groups):
#     353     yield train, test
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:85, in BaseCrossValidator.split(self, X, y, groups)
#      83 X, y, groups = indexable(X, y, groups)
#      84 indices = np.arange(_num_samples(X))
# ---> 85 for test_index in self._iter_test_masks(X, y, groups):
#      86     train_index = indices[np.logical_not(test_index)]
#      87     test_index = indices[test_index]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:733, in StratifiedKFold._iter_test_masks(self, X, y, groups)
#     732 def _iter_test_masks(self, X, y=None, groups=None):
# --> 733     test_folds = self._make_test_folds(X, y)
#     734     for i in range(self.n_splits):
#     735         yield test_folds == i
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:676, in StratifiedKFold._make_test_folds(self, X, y)
#     674 allowed_target_types = ("binary", "multiclass")
#     675 if type_of_target_y not in allowed_target_types:
# --> 676     raise ValueError(
#     677         "Supported target types are: {}. Got {!r} instead.".format(
#     678             allowed_target_types, type_of_target_y
#     679         )
#     680     )
#     682 y = column_or_1d(y)
#     684 _, y_idx, y_inv = np.unique(y, return_index=True, return_inverse=True)
#
# ValueError: Supported target types are: ('binary', 'multiclass'). Got 'multilabel-indicator' instead.
