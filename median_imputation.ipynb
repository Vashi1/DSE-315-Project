# %%
from Data_loader import dummy_enc
from Data_imputation import median_imputer
import pandas as pd
from sklearn.preprocessing import StandardScaler
from FeatureSelection import PCA_data
from decision_tree_Classifiers import dt_kn_classifier_pca, dt_kn_classifier_pca_kfold, dt_kn_classifier_pca_stratfold
from GridSearch_params import split_data

# %%
data = pd.read_csv('train.csv')
y = data.outcome
x = data.drop(['outcome'], axis=1)

# %%
sscaler = StandardScaler()
X_data_enc = dummy_enc(x)
x_data_mean = median_imputer(X_data_enc)
X_data_sc = sscaler.fit_transform(x_data_mean)

# %%
x_data_pca = PCA_data(X_data_sc)

# %%
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y)

# %%
dt_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# Decision Tree Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.52      0.79      0.63        72
#   euthanized       0.78      0.26      0.39        54
#        lived       0.69      0.69      0.69       121
#
#     accuracy                           0.62       247
#    macro avg       0.66      0.58      0.57       247
# weighted avg       0.66      0.62      0.61       247
#
# Plotting the Confusion Matrix

# %%
dt_kn_classifier_pca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Decision Tree Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.64
# 	Precision Score(Weighted): 0.66
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %%
dt_kn_classifier_pca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Decision Tree Classifier with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.63
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.61
# 	Recall Score(Weighted): 0.64
#
# 	F1 Score(Macro): 0.64
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.64
# Plotting the Confusion Matrix

# %%
from random_forest_classifier import rft_kn_classifier_pca, rft_kn_classifier_pca_kfold, rft_kn_classifier_pca_stratfold

# %%
rft_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# Random Forest Tree Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.60      0.71      0.65        72
#   euthanized       0.85      0.41      0.55        54
#        lived       0.71      0.80      0.75       121
#
#     accuracy                           0.69       247
#    macro avg       0.72      0.64      0.65       247
# weighted avg       0.71      0.69      0.68       247
#
# Plotting the Confusion Matrix

# %%
rft_kn_classifier_pca_kfold(x_data_pca,y,  x_tr, x_te, y_tr, y_te)
# Out:
# Random Forest Tree Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.61
# 	Recall Score(Weighted): 0.66
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.67
# Plotting the Confusion Matrix

# %%
rft_kn_classifier_pca_stratfold(x_data_pca, y,x_tr, x_te, y_tr, y_te )
# Out:
# Random Forest Tree Classifier with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.68
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.67
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.67
# Plotting the Confusion Matrix

# %%
from logistic_regression_classifier import lr_kn_classifier_pca, lr_kn_classifier_pca_kfold, lr_kn_classifier_pca_stratfold

# %%
lr_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# Logistic Regression Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.62      0.74      0.67        72
#   euthanized       0.70      0.52      0.60        54
#        lived       0.74      0.74      0.74       121
#
#     accuracy                           0.69       247
#    macro avg       0.68      0.66      0.67       247
# weighted avg       0.69      0.69      0.69       247
#
# Plotting the Confusion Matrix

# %%
lr_kn_classifier_pca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Random Forest Tree Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.68
# 	Precision Score(Weighted): 0.69
#
# 	Recall Score(Macro): 0.67
# 	Recall Score(Weighted): 0.69
#
# 	F1 Score(Macro): 0.69
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.69
# Plotting the Confusion Matrix

# %%
lr_kn_classifier_pca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Logistic Regression Classifier with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.68
# 	Precision Score(Weighted): 0.69
#
# 	Recall Score(Macro): 0.67
# 	Recall Score(Weighted): 0.69
#
# 	F1 Score(Macro): 0.69
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.69
# Plotting the Confusion Matrix

# %%
from XGBoost_classifier import xgb_kn_classifier_pca, xgb_kn_classifier_pca_kfold, xgb_kn_classifier_pca_stratfold

# %%
data = pd.read_csv('train.csv')
y = data.outcome
x = data.drop(['outcome'], axis=1)
y_enc = dummy_enc(y)
sscaler = StandardScaler()
X_data_enc = dummy_enc(x)
x_data_mean = median_imputer(X_data_enc)
X_data_sc = sscaler.fit_transform(x_data_mean)
x_data_pca = PCA_data(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y_enc)

# %%
xgb_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# XGBoosting Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
# /home/aarvee/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.60      0.58      0.59        72
#            1       0.72      0.39      0.51        54
#            2       0.74      0.66      0.70       121
#
#    micro avg       0.69      0.58      0.63       247
#    macro avg       0.69      0.54      0.60       247
# weighted avg       0.70      0.58      0.63       247
#  samples avg       0.55      0.58      0.56       247
#
# Plotting the Confusion Matrix

# %%
xgb_kn_classifier_pca_kfold(x_data_pca, y_enc, x_tr, x_te, y_tr, y_te)
# Out:
# XGBoosting Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.71
#
# 	Recall Score(Macro): 0.55
# 	Recall Score(Weighted): 0.59
#
# 	F1 Score(Macro): 0.64
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.55
# Plotting the Confusion Matrix

# %%
xgb_kn_classifier_pca_stratfold(x_data_pca, y_enc, x_tr, x_te, y_tr, y_te)
# Out:
# XGBoosting with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.67
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.64
# 	Recall Score(Weighted): 0.67
#
# 	F1 Score(Macro): 0.67
# 	F1 Score(Weighted): 0.67
# 	Accuracy Score: 0.67
# Plotting the Confusion Matrix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 xgb_kn_classifier_pca_stratfold(x_data_pca, y_enc, x_tr, x_te, y_tr, y_te)
#
# File ~/Desktop/DSE-315-Project/XGBoost_classifier.py:92, in xgb_kn_classifier_pca_stratfold(x_data, y_data, x_tr, x_te, y_tr, y_te)
#      90 print(f"\tAccuracy Score: {nested_score_acc.mean():.2f}")
#      91 print("Plotting the Confusion Matrix")
# ---> 92 y_pr = cross_val_predict(lr_cl_kn_pca_stratf, x_te, y_te, cv = outer_cv)
#      93 cormat = confusion_matrix(np.array(y_te).argmax(axis = 1), np.array(y_pr).argmax(axis = 1))
#      94 sns.heatmap(cormat, annot=True, fmt = 'g')
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:1010, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#    1007 X, y, groups = indexable(X, y, groups)
#    1009 cv = check_cv(cv, y, classifier=is_classifier(estimator))
# -> 1010 splits = list(cv.split(X, y, groups))
#    1012 test_indices = np.concatenate([test for _, test in splits])
#    1013 if not _check_is_permutation(test_indices, _num_samples(X)):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:377, in _BaseKFold.split(self, X, y, groups)
#     369 if self.n_splits > n_samples:
#     370     raise ValueError(
#     371         (
#     372             "Cannot have number of splits n_splits={0} greater"
#     373             " than the number of samples: n_samples={1}."
#     374         ).format(self.n_splits, n_samples)
#     375     )
# --> 377 for train, test in super().split(X, y, groups):
#     378     yield train, test
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:108, in BaseCrossValidator.split(self, X, y, groups)
#     106 X, y, groups = indexable(X, y, groups)
#     107 indices = np.arange(_num_samples(X))
# --> 108 for test_index in self._iter_test_masks(X, y, groups):
#     109     train_index = indices[np.logical_not(test_index)]
#     110     test_index = indices[test_index]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:758, in StratifiedKFold._iter_test_masks(self, X, y, groups)
#     757 def _iter_test_masks(self, X, y=None, groups=None):
# --> 758     test_folds = self._make_test_folds(X, y)
#     759     for i in range(self.n_splits):
#     760         yield test_folds == i
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:701, in StratifiedKFold._make_test_folds(self, X, y)
#     699 allowed_target_types = ("binary", "multiclass")
#     700 if type_of_target_y not in allowed_target_types:
# --> 701     raise ValueError(
#     702         "Supported target types are: {}. Got {!r} instead.".format(
#     703             allowed_target_types, type_of_target_y
#     704         )
#     705     )
#     707 y = column_or_1d(y)
#     709 _, y_idx, y_inv = np.unique(y, return_index=True, return_inverse=True)
#
# ValueError: Supported target types are: ('binary', 'multiclass'). Got 'multilabel-indicator' instead.
