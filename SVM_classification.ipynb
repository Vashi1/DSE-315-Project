# %%
from Data_loader import dummy_enc
from Data_imputation import mean_imputer, median_imputer, mf_imputer, knn_imputer
import pandas as pd
from sklearn.preprocessing import StandardScaler
from FeatureSelection import PCA_data, Kernal_PCA, TrSVD
from support_vector_classifier import svm_kn_classifier_pca, svm_kn_classifier_pca_kfold, svm_kn_classifier_pca_stratfold 
from GridSearch_params import split_data

# %%
data = pd.read_csv('train.csv')
y = data.outcome
x = data.drop(['outcome'], axis=1)

# %% [markdown]
# *Mean Imputer and PCA*

# %%
sscaler = StandardScaler()
X_data_enc = dummy_enc(x)
x_data_mean = mean_imputer(X_data_enc)
X_data_sc = sscaler.fit_transform(x_data_mean)

# %%
x_data_pca = PCA_data(X_data_sc)

# %%
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y)

# %%
svm_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.62      0.75      0.68        72
#   euthanized       0.76      0.48      0.59        54
#        lived       0.73      0.76      0.74       121
#
#     accuracy                           0.70       247
#    macro avg       0.71      0.66      0.67       247
# weighted avg       0.71      0.70      0.69       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.66
# 	Recall Score(Weighted): 0.69
#
# 	F1 Score(Macro): 0.69
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.69
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.67
# 	Recall Score(Weighted): 0.70
#
# 	F1 Score(Macro): 0.70
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.70
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_kpca, svm_kn_classifier_kpca_kfold, svm_kn_classifier_kpca_stratfold

# %%
x_data_kpca = Kernal_PCA(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_kpca, y)

# %%
svm_kn_classifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.54      0.74      0.62        72
#   euthanized       0.73      0.44      0.55        54
#        lived       0.76      0.72      0.74       121
#
#     accuracy                           0.66       247
#    macro avg       0.67      0.63      0.64       247
# weighted avg       0.69      0.66      0.66       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_kfold(x_data_kpca,y,  x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Kernel PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.66
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.66
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_stratfold(x_data_kpca, y,x_tr, x_te, y_tr, y_te )
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.64
#
# 	F1 Score(Macro): 0.64
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.64
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_trsvd, svm_kn_classifier_trsvd_kfold, svm_kn_classifier_trsvd_stratfold

# %%
x_data_trsvd = TrSVD(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_trsvd, y)

# %%
svm_kn_classifier_trsvd(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Truncated SVD Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.54      0.74      0.62        72
#   euthanized       0.75      0.44      0.56        54
#        lived       0.75      0.72      0.73       121
#
#     accuracy                           0.66       247
#    macro avg       0.68      0.63      0.64       247
# weighted avg       0.69      0.66      0.66       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_kfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Truncated SVD Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.66
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_stratfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Truncated SVD Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %% [markdown]
# *Median Imputer and PCA*

# %%
sscaler = StandardScaler()
X_data_enc = dummy_enc(x)
x_data_mean = median_imputer(X_data_enc)
X_data_sc = sscaler.fit_transform(x_data_mean)

# %%
x_data_pca = PCA_data(X_data_sc)

# %%
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y)

# %%
svm_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.62      0.74      0.68        72
#   euthanized       0.76      0.52      0.62        54
#        lived       0.74      0.76      0.75       121
#
#     accuracy                           0.70       247
#    macro avg       0.71      0.67      0.68       247
# weighted avg       0.71      0.70      0.70       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.67
# 	Recall Score(Weighted): 0.70
#
# 	F1 Score(Macro): 0.70
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.70
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.66
# 	Recall Score(Weighted): 0.70
#
# 	F1 Score(Macro): 0.70
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.70
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_kpca, svm_kn_classifier_kpca_kfold, svm_kn_classifier_kpca_stratfold

# %%
x_data_kpca = Kernal_PCA(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_kpca, y)

# %%
svm_kn_classifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.54      0.76      0.64        72
#   euthanized       0.77      0.44      0.56        54
#        lived       0.76      0.72      0.74       121
#
#     accuracy                           0.67       247
#    macro avg       0.69      0.64      0.65       247
# weighted avg       0.70      0.67      0.67       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_kfold(x_data_kpca,y,  x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Kernel PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.66
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.66
# 	Accuracy Score: 0.66
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_stratfold(x_data_kpca, y,x_tr, x_te, y_tr, y_te )
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.66
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_trsvd, svm_kn_classifier_trsvd_kfold, svm_kn_classifier_trsvd_stratfold

# %%
x_data_trsvd = TrSVD(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_trsvd, y)

# %%
svm_kn_classifier_trsvd(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Truncated SVD Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.55      0.76      0.64        72
#   euthanized       0.78      0.46      0.58        54
#        lived       0.76      0.72      0.74       121
#
#     accuracy                           0.68       247
#    macro avg       0.70      0.65      0.65       247
# weighted avg       0.70      0.68      0.67       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_kfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Truncated SVD Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.66
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.66
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_stratfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Truncated SVD Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.66
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %% [markdown]
# *Most Frequent Imputer and PCA*

# %%
sscaler = StandardScaler()
X_data_enc = dummy_enc(x)
x_data_mf = mf_imputer(X_data_enc)
X_data_sc = sscaler.fit_transform(x_data_mf)

# %%
x_data_pca = PCA_data(X_data_sc)

# %%
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y)

# %%
svm_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.62      0.74      0.67        72
#   euthanized       0.76      0.52      0.62        54
#        lived       0.73      0.75      0.74       121
#
#     accuracy                           0.70       247
#    macro avg       0.70      0.67      0.68       247
# weighted avg       0.70      0.70      0.69       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.66
# 	Recall Score(Weighted): 0.69
#
# 	F1 Score(Macro): 0.69
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.69
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.70
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.67
# 	Recall Score(Weighted): 0.70
#
# 	F1 Score(Macro): 0.70
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.70
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_kpca, svm_kn_classifier_kpca_kfold, svm_kn_classifier_kpca_stratfold

# %%
x_data_kpca = Kernal_PCA(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_kpca, y)

# %%
svm_kn_classifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.55      0.78      0.64        72
#   euthanized       0.78      0.46      0.58        54
#        lived       0.76      0.71      0.74       121
#
#     accuracy                           0.68       247
#    macro avg       0.70      0.65      0.65       247
# weighted avg       0.70      0.68      0.67       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_kfold(x_data_kpca,y,  x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Kernel PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.66
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.66
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_stratfold(x_data_kpca, y,x_tr, x_te, y_tr, y_te )
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_trsvd, svm_kn_classifier_trsvd_kfold, svm_kn_classifier_trsvd_stratfold

# %%
x_data_trsvd = TrSVD(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_trsvd, y)

# %%
svm_kn_classifier_trsvd(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Truncated SVD Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.55      0.78      0.65        72
#   euthanized       0.77      0.44      0.56        54
#        lived       0.76      0.72      0.74       121
#
#     accuracy                           0.68       247
#    macro avg       0.70      0.65      0.65       247
# weighted avg       0.70      0.68      0.67       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_kfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Truncated SVD Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.65
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_stratfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Truncated SVD Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.61
# 	Recall Score(Weighted): 0.64
#
# 	F1 Score(Macro): 0.64
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.64
# Plotting the Confusion Matrix

# %% [markdown]
# *KNN Imputer and PCA*

# %%
sscaler = StandardScaler()
X_data_enc = dummy_enc(x)
x_data_mean = knn_imputer(X_data_enc)
X_data_sc = sscaler.fit_transform(x_data_mean)

# %%
x_data_pca = PCA_data(X_data_sc)

# %%
x_tr, x_te, y_tr, y_te = split_data(x_data_pca, y)

# %%
svm_kn_classifier_pca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.61      0.74      0.67        72
#   euthanized       0.74      0.48      0.58        54
#        lived       0.72      0.74      0.73       121
#
#     accuracy                           0.68       247
#    macro avg       0.69      0.65      0.66       247
# weighted avg       0.69      0.68      0.68       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_kfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.66
# 	Recall Score(Weighted): 0.69
#
# 	F1 Score(Macro): 0.69
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.69
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_pca_stratfold(x_data_pca, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.69
# 	Precision Score(Weighted): 0.70
#
# 	Recall Score(Macro): 0.66
# 	Recall Score(Weighted): 0.69
#
# 	F1 Score(Macro): 0.69
# 	F1 Score(Weighted): 0.69
# 	Accuracy Score: 0.69
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_kpca, svm_kn_classifier_kpca_kfold, svm_kn_classifier_kpca_stratfold

# %%
x_data_kpca = Kernal_PCA(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_kpca, y)

# %%
svm_kn_classifier_kpca(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Kernel PCA Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.55      0.74      0.63        72
#   euthanized       0.77      0.50      0.61        54
#        lived       0.77      0.74      0.75       121
#
#     accuracy                           0.68       247
#    macro avg       0.70      0.66      0.66       247
# weighted avg       0.71      0.68      0.68       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_kfold(x_data_kpca,y,  x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Kernel PCA Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.66
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.66
# 	Accuracy Score: 0.66
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_kpca_stratfold(x_data_kpca, y,x_tr, x_te, y_tr, y_te )
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Kernel PCA Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix

# %%
from support_vector_classifier import svm_kn_classifier_trsvd, svm_kn_classifier_trsvd_kfold, svm_kn_classifier_trsvd_stratfold

# %%
x_data_trsvd = TrSVD(X_data_sc)
x_tr, x_te, y_tr, y_te = split_data(x_data_trsvd, y)

# %%
svm_kn_classifier_trsvd(x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier without using any Cross-Validation Technique and Truncated SVD Feature Selection
# Classification Report
#               precision    recall  f1-score   support
#
#         died       0.55      0.74      0.63        72
#   euthanized       0.77      0.50      0.61        54
#        lived       0.77      0.74      0.75       121
#
#     accuracy                           0.68       247
#    macro avg       0.70      0.66      0.66       247
# weighted avg       0.71      0.68      0.68       247
#
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_kfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with K-Fold Cross-Validation Technique(K = 10) and Truncated SVD Feature Extraction
# Classification Report
# 	Precision Score(Macro): 0.66
# 	Precision Score(Weighted): 0.67
#
# 	Recall Score(Macro): 0.63
# 	Recall Score(Weighted): 0.66
#
# 	F1 Score(Macro): 0.66
# 	F1 Score(Weighted): 0.66
# 	Accuracy Score: 0.66
# Plotting the Confusion Matrix

# %%
svm_kn_classifier_trsvd_stratfold(x_data_trsvd, y, x_tr, x_te, y_tr, y_te)
# Out:
# Support Vector Classifier with Stratified K-Fold Cross-Validation Technique and Truncated SVD Feature Extraction Technique
# Classification Report
# 	Precision Score(Macro): 0.65
# 	Precision Score(Weighted): 0.65
#
# 	Recall Score(Macro): 0.62
# 	Recall Score(Weighted): 0.65
#
# 	F1 Score(Macro): 0.65
# 	F1 Score(Weighted): 0.64
# 	Accuracy Score: 0.65
# Plotting the Confusion Matrix
